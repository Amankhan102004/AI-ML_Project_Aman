# %%
# !pip install langchain langchain-community langchain-core langchain-openai langchain-huggingface transformers datasets huggingface_hub accelerate diffusers peft bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 60.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.9/554.9 kB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 18.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.3
#     Uninstalling langchain-core-1.4.3:
#       Successfully uninstalled langchain-core-1.4.3
# ...

# %%
from langchain_openai import OpenAIEmbeddings

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# False

# %%
import os
from google.colab import userdata

# Colab Secret से की (key) लोड करें
os.environ["OPENAI_API_KEY"] = "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"

# %%
embedding = OpenAIEmbeddings(
    model="text-embedding-3-large",
    dimensions=32
)

# %%
result=embedding.embed_query("Delhi is the capital of india")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_1745/561820454.py in <cell line: 0>()
# ----> 1 result=embedding.embed_query("Delhi is the capital of india")
#
# /usr/local/lib/python3.12/dist-packages/langchain_openai/embeddings/base.py in embed_query(self, text, **kwargs)
#     803         """
#     804         self._ensure_sync_client_available()
# --> 805         return self.embed_documents([text], **kwargs)[0]
#     806
#     807     async def aembed_query(self, text: str, **kwargs: Any) -> list[float]:
#
# /usr/local/lib/python3.12/dist-packages/langchain_openai/embeddings/base.py in embed_documents(self, texts, chunk_size, **kwargs)
#     753         # This could be optimized to avoid double work when all texts are short enough.
#     754         engine = cast(str, self.deployment)
# --> 755         return self._get_len_safe_embeddings(
# ...

# %%
print(str(result))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1745/2080022034.py in <cell line: 0>()
# ----> 1 print(str(result))
#
# NameError: name 'result' is not defined
